# %% [markdown]
# **MINI PROJECT | ASSIGNMENT ON PANDAS by Israel Afolabi
# **

# %%
# we import pandas library
import pandas as pd

# %%
ff = pd.read_csv('fifa19.csv')
ff.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0       94.0
# 1  https://cdn.sofifa.org/flags/38.png     94.0       94.0
# 2  https://cdn.sofifa.org/flags/54.png     92.0       93.0
# 3  https://cdn.sofifa.org/flags/45.png     91.0       93.0
# ...

# %%
# Write a pandas code to explore the dataset
ff.describe()
# Out:
#         Unnamed: 0             ID          Age      Overall    Potential  \
# count  8336.000000    8336.000000  8336.000000  8335.000000  8335.000000
# mean   4167.500000  203315.380278    26.954655    72.145771    74.820276
# std    2406.540255   30221.665111     4.101485     4.220664     5.146484
# min       0.000000      16.000000    17.000000    67.000000    67.000000
# 25%    2083.750000  189575.750000    24.000000    69.000000    71.000000
# 50%    4167.500000  207745.500000    27.000000    71.000000    74.000000
# 75%    6251.250000  224255.000000    30.000000    74.000000    78.000000
# max    8335.000000  246405.000000    45.000000    94.000000    95.000000
#
#            Special  International Reputation    Weak Foot  Skill Moves  \
# count  8335.000000               8335.000000  8335.000000  8335.000000
# mean   1738.547690                  1.243191     3.061548     2.642831
# std     243.267523                  0.550983     0.693608     0.808055
# ...

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                8336 non-null   int64
#  1   ID                        8336 non-null   int64
#  2   Name                      8336 non-null   object
#  3   Age                       8336 non-null   int64
#  4   Photo                     8336 non-null   object
#  5   Nationality               8336 non-null   object
#  6   Flag                      8336 non-null   object
#  7   Overall                   8335 non-null   float64
#  8   Potential                 8335 non-null   float64
#  9   Club                      8195 non-null   object
#  10  Club Logo                 8335 non-null   object
#  11  Value                     8335 non-null   object
#  12  Wage                      8335 non-null   object
# ...

# %%
ff.shape
# Out:
# (8336, 89)

# %%
# Task 2: Perform a complete data cleaning process in the dataset (Check for Null Values, Duplicates)

# %%
# To check for null values from the dataset
ff_null = ff.isnull().sum()
ff_null
# Out:
# Unnamed: 0          0
# ID                  0
# Name                0
# Age                 0
# Photo               0
#                  ...
# GKHandling          1
# GKKicking           1
# GKPositioning       1
# GKReflexes          1
# Release Clause    803
# Length: 89, dtype: int64

# %%
# Check for the first 15 Oldest Player
ff
# Out:
#       Unnamed: 0      ID               Name  Age  \
# 0              0  158023           L. Messi   31
# 1              1   20801  Cristiano Ronaldo   33
# 2              2  190871          Neymar Jr   26
# 3              3  193080             De Gea   27
# 4              4  192985       K. De Bruyne   27
# ...          ...     ...                ...  ...
# 8331        8331  214684           S. Jaime   31
# 8332        8332  225692           M. Bader   21
# 8333        8333  227740        D. Arboleda   23
# 8334        8334  233372         B. Merlini   22
# 8335        8335  204445           M. Smith   29
#
#                                                Photo       Nationality  \
# 0     https://cdn.sofifa.org/players/4/19/158023.png         Argentina
# 1      https://cdn.sofifa.org/players/4/19/20801.png          Portugal
# 2     https://cdn.sofifa.org/players/4/19/190871.png            Brazil
# 3     https://cdn.sofifa.org/players/4/19/193080.png             Spain
# ...

# %%
# Check for the first 15 Oldest Player
age = ff.sort_values('Age', ascending=False)
age.head(15)
age[['Name','Age']]
# Out:
#                  Name  Age
# 4741         O. Pérez   45
# 4228         B. Nivet   41
# 7225         C. Muñoz   41
# 1120        J. Villar   41
# 41          G. Buffon   40
# ...               ...  ...
# 7320        K. Pierie   17
# 8191         A. Gomes   17
# 7566        E. Håland   17
# 7217     Sergio Gómez   17
# 1143  Vinícius Júnior   17
#
# [8336 rows x 2 columns]

# %%
# Who is the player that has the highest release clause
# ff
# ff['Name', 'Release Clause']
highest_release = ff[['Name','Release Clause']]
# highest_release
highest_release.sort_values('Release Clause', ascending=False)
# The player with the highest relase clause is Léo Matos
# Out:
#              Name Release Clause
# 2584   F. Carrizo            €9M
# 2897     Perdigão            €9M
# 1221      J. Sosa            €9M
# 2493     J. Plata            €9M
# 2952     I. Mbaye            €9M
# ...           ...            ...
# 8296    B. Baráth            NaN
# 8310   R. Perraud            NaN
# 8313      P. Eler            NaN
# 8333  D. Arboleda            NaN
# 8335     M. Smith            NaN
#
# [8336 rows x 2 columns]

# %%
# How many unique Nationalities is in the dataset
# ff
uniqueNationalities = ff['Nationality'].nunique()
uniqueNationalities
# we had 164 unique countries
# Out:
# 139

# %%
# Generate all the players by Nationality "NIgeria"
#ff
# Nationality
NigeriaPlayers = ff.loc[ff['Nationality'].str.contains("Nigeria")]
NigeriaPlayers
# Out:
#       Unnamed: 0      ID          Name  Age  \
# 425          425  226790      W. Ndidi   21
# 789          789  213655      A. Iwobi   22
# 858          858  172962      V. Moses   27
# 1022        1022  185195     O. Ighalo   29
# 1296        1296  234045   H. Onyekuru   21
# ...          ...     ...           ...  ...
# 7371        7371  212158      O. Osawe   24
# 7426        7426  231627      U. Sadiq   21
# 7575        7575  241135    J. Collins   23
# 7699        7699  221197  F. Onyedinma   21
# 7849        7849  209709  B. Edomwonyi   23
#
#                                                Photo Nationality  \
# 425   https://cdn.sofifa.org/players/4/19/226790.png     Nigeria
# 789   https://cdn.sofifa.org/players/4/19/213655.png     Nigeria
# 858   https://cdn.sofifa.org/players/4/19/172962.png     Nigeria
# 1022  https://cdn.sofifa.org/players/4/19/185195.png     Nigeria
# 1296  https://cdn.sofifa.org/players/4/19/234045.png     Nigeria
# ...

# %%
# Who is the oldest player in Nigeria and France
NigeriaPlayers
NigeriaPlayers.sort_values('Age', ascending=False)
# I. Uche (34) is the Oldest player in Nigeria
# Out:
#       Unnamed: 0      ID         Name  Age  \
# 5097        5097  146011      I. Uche   34
# 3604        3604  164478     C. Obasi   32
# 7295        7295  176038    J. Akpala   31
# 1615        1615  188182   L. Balogun   30
# 5633        5633  186876   E. Ambrose   29
# ...          ...     ...          ...  ...
# 4903        4903  236836  O. Okwonkwo   20
# 2431        2431  239015    E. Dennis   20
# 2382        2382  237207      S. Kalu   20
# 6673        6673  239120     F. Uzoho   19
# 5123        5123  232293   V. Osimhen   19
#
#                                                Photo Nationality  \
# 5097  https://cdn.sofifa.org/players/4/19/146011.png     Nigeria
# 3604  https://cdn.sofifa.org/players/4/19/164478.png     Nigeria
# 7295  https://cdn.sofifa.org/players/4/19/176038.png     Nigeria
# 1615  https://cdn.sofifa.org/players/4/19/188182.png     Nigeria
# 5633  https://cdn.sofifa.org/players/4/19/186876.png     Nigeria
# ...

# %%
# Prepare a simple report for your findings
